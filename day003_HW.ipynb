# %%
import urllib.request
import zipfile

res = "http://opendata.cwb.gov.tw/govdownload?dataid=F-D0047-093&authorizationkey=rdec-key-123-45678-011121314"
urllib.request.urlretrieve(res, "C:/Users/amy10/Desktop/大學課程/python爬蟲/data/day003.zip")
f = zipfile.ZipFile('C:/Users/amy10/Desktop/大學課程/python爬蟲/data/day003.zip')
f.extractall('C:/Users/amy10/Desktop/大學課程/python爬蟲/data/day003')

# %%
import os, sys

# 打开文件
dirs = os.listdir( 'C:/Users/amy10/Desktop/大學課程/python爬蟲/data/day003' )

# 输出所有文件和文件夹
for file in dirs:
    print(file)
# Out:
# 09007_72hr_CH.xml
# 09007_72hr_EN.xml
# 09007_Week24_CH.xml
# 09007_Week24_EN.xml
# 09007_Weekday_CH.xml
# 09007_Weekday_EN.xml
# 09020_72hr_CH.xml
# 09020_72hr_EN.xml
# 09020_Week24_CH.xml
# 09020_Week24_EN.xml
# 09020_Weekday_CH.xml
# 09020_Weekday_EN.xml
# 10002_72hr_CH.xml
# 10002_72hr_EN.xml
# 10002_Week24_CH.xml
# 10002_Week24_EN.xml
# 10002_Weekday_CH.xml
# 10002_Weekday_EN.xml
# 10004_72hr_CH.xml
# 10004_72hr_EN.xml
# 10004_Week24_CH.xml
# 10004_Week24_EN.xml
# 10004_Weekday_CH.xml
# 10004_Weekday_EN.xml
# 10005_72hr_CH.xml
# 10005_72hr_EN.xml
# 10005_Week24_CH.xml
# 10005_Week24_EN.xml
# 10005_Weekday_CH.xml
# 10005_Weekday_EN.xml
# 10007_72hr_CH.xml
# 10007_72hr_EN.xml
# 10007_Week24_CH.xml
# 10007_Week24_EN.xml
# 10007_Weekday_CH.xml
# 10007_Weekday_EN.xml
# 10008_72hr_CH.xml
# 10008_72hr_EN.xml
# 10008_Week24_CH.xml
# 10008_Week24_EN.xml
# 10008_Weekday_CH.xml
# 10008_Weekday_EN.xml
# 10009_72hr_CH.xml
# 10009_72hr_EN.xml
# 10009_Week24_CH.xml
# 10009_Week24_EN.xml
# ...

# %%
import xmltodict

d = dict(xmltodict.parse(xml))

# %%
datasetDescription = d['cwbopendata']['dataset']['datasetInfo']['datasetDescription']
print(datasetDescription)
# Out:
# OrderedDict([('locationsName', '高雄市'), ('location', [OrderedDict([('locationName', '鹽埕區'), ('geocode', '6400100'), ('lat', '22.626497'), ('lon', '120.278707'), ('weatherElement', [OrderedDict([('elementName', 'T'), ('description', '溫度'), ('time', [OrderedDict([('dataTime', '2020-03-29T18:00:00+08:00'), ('elementValue', OrderedDict([('value', '24'), ('measures', '攝氏度')]))]), OrderedDict([('dataTime', '2020-03-29T21:00:00+08:00'), ('elementValue', OrderedDict([('value', '23'), ('measures', '攝氏度')]))]), OrderedDict([('dataTime', '2020-03-30T00:00:00+08:00'), ('elementValue', OrderedDict([('value', '22'), ('measures', '攝氏度')]))]), OrderedDict([('dataTime', '2020-03-30T03:00:00+08:00'), ('elementValue', OrderedDict([('value', '22'), ('measures', '攝氏度')]))]), OrderedDict([('dataTime', '2020-03-30T06:00:00+08:00'), ('elementValue', OrderedDict([('value', '22'), ('measures', '攝氏度')]))]), OrderedDict([('dataTime', '2020-03-30T09:00:00+08:00'), ('elementValue', OrderedDict([('value', '24'), ('
# ...

# %%
# 1. 請問高雄市有多少地區有溫度資料？
location=d['cwbopendata']['dataset']['locations']['location']
print(len(location))
# Out:
# 38

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
location=d['cwbopendata']['dataset']['locations']['location']
#第一筆資料[0]
for location in location:
    print("地區：",location['locationName'],sep='',end='/')
    print("溫度：",location['weatherElement'][0]['time'][0]['elementValue']['value'],sep='',end='/')
    print("時間：",location['weatherElement'][0]['time'][0]['dataTime'],sep='')
# Out:
# 地區：鹽埕區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：鼓山區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：左營區/溫度：23/時間：2020-03-29T18:00:00+08:00
# 地區：楠梓區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：三民區/溫度：23/時間：2020-03-29T18:00:00+08:00
# 地區：新興區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：前金區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：苓雅區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：前鎮區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：旗津區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：小港區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：鳳山區/溫度：25/時間：2020-03-29T18:00:00+08:00
# 地區：林園區/溫度：25/時間：2020-03-29T18:00:00+08:00
# 地區：大寮區/溫度：25/時間：2020-03-29T18:00:00+08:00
# 地區：大樹區/溫度：25/時間：2020-03-29T18:00:00+08:00
# 地區：大社區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：仁武區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：鳥松區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：岡山區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：橋頭區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：燕巢區/溫度：24/時間：2020-03-29T18:00:00+08:00
# 地區：田寮區/溫度：23/時間：2020-03-29T18:00:00+08:00
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

location=d['cwbopendata']['dataset']['locations']['location']

location1 = location[0]
print(location1['locationName'])
#['weatherElement'][0]有許多的天氣資訊其中第一個是溫度
for i in location1['weatherElement'][0]['time']:
    print("時間：",i['dataTime'],sep='',end='/')
    print("溫度：",i['elementValue']['value'],sep='')
# Out:
# 鹽埕區
# 時間：2020-03-29T18:00:00+08:00/溫度：24
# 時間：2020-03-29T21:00:00+08:00/溫度：23
# 時間：2020-03-30T00:00:00+08:00/溫度：22
# 時間：2020-03-30T03:00:00+08:00/溫度：22
# 時間：2020-03-30T06:00:00+08:00/溫度：22
# 時間：2020-03-30T09:00:00+08:00/溫度：24
# 時間：2020-03-30T12:00:00+08:00/溫度：28
# 時間：2020-03-30T15:00:00+08:00/溫度：28
# 時間：2020-03-30T18:00:00+08:00/溫度：27
# 時間：2020-03-30T21:00:00+08:00/溫度：26
# 時間：2020-03-31T00:00:00+08:00/溫度：25
# 時間：2020-03-31T03:00:00+08:00/溫度：24
# 時間：2020-03-31T06:00:00+08:00/溫度：24
# 時間：2020-03-31T09:00:00+08:00/溫度：26
# 時間：2020-03-31T12:00:00+08:00/溫度：29
# 時間：2020-03-31T15:00:00+08:00/溫度：29
# 時間：2020-03-31T18:00:00+08:00/溫度：28
# 時間：2020-03-31T21:00:00+08:00/溫度：26
# 時間：2020-04-01T00:00:00+08:00/溫度：25
# 時間：2020-04-01T03:00:00+08:00/溫度：24
# 時間：2020-04-01T06:00:00+08:00/溫度：24
# 時間：2020-04-01T09:00:00+08:00/溫度：26
# 時間：2020-04-01T12:00:00+08:00/溫度：28
# 時間：2020-04-01T15:00:00+08:00/溫度：28
